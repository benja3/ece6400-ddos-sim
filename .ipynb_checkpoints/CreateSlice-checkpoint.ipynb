# %%
# Import libraries
from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager
from ipaddress import ip_address, IPv4Address, IPv6Address, IPv4Network, IPv6Network
import json
import traceback
import numpy as np

fablib = fablib_manager()
fablib.show_config()
# Out:
# <style type="text/css">
# #T_bc4a5 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_bc4a5 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_bc4a5 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_bc4a5_row0_col0, #T_bc4a5_row0_col1, #T_bc4a5_row1_col0, #T_bc4a5_row1_col1, #T_bc4a5_row2_col0, #T_bc4a5_row2_col1, #T_bc4a5_row3_col0, #T_bc4a5_row3_col1, #T_bc4a5_row4_col0, #T_bc4a5_row4_col1, #T_bc4a5_row5_col0, #T_bc4a5_row5_col1, #T_bc4a5_row6_col0, #T_bc4a5_row6_col1, #T_bc4a5_row7_col0, #T_bc4a5_row7_col1, #T_bc4a5_row8_col0, #T_bc4a5_row8_col1, #T_bc4a5_row9_col0, #T_bc4a5_row9_col1, #T_bc4a5_row10_col0, #T_bc4a5_row10_col1, #T_bc4a5_row11_col0, #T_bc4a5_row11_col1, #T_bc4a5_row12_col0, #T_bc4a5_row12_col1, #T_bc4a5_row13_col0, #T_bc4a5_row13_col1, #T_bc4a5_row14_col0, #T_bc4a5_row14_col1, #T_bc4a5_row15_col0, #T_bc4a5_row15_col1, #T_bc4a5_row16_col0, #T_bc4a5_row16_col1, #T_bc4a5_row17_col0, #T_bc4a5_row17_col1, #T_bc4a5_row18_col0, #T_bc4a5_row18_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_bc4a5">
#   <caption>FABlib Config</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_bc4a5_row0_col0" class="data row0 col0" >Credential Manager</td>
#       <td id="T_bc4a5_row0_col1" class="data row0 col1" >cm.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_bc4a5_row1_col0" class="data row1 col0" >Orchestrator</td>
#       <td id="T_bc4a5_row1_col1" class="data row1 col1" >orchestrator.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_bc4a5_row2_col0" class="data row2 col0" >Project ID</td>
#       <td id="T_bc4a5_row2_col1" class="data row2 col1" >0508639f-d515-44c8-b922-cf4cf000b6d9</td>
#     </tr>
#     <tr>
#       <td id="T_bc4a5_row3_col0" class="data row3 col0" >Token File</td>
#       <td id="T_bc4a5_row3_col1" class="data row3 col1" >/home/fabric/.tokens.json</td>
#     </tr>
#     <tr>
#       <td id="T_bc4a5_row4_col0" class="data row4 col0" >Bastion Host</td>
#       <td id="T_bc4a5_row4_col1" class="data row4 col1" >bastion.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_bc4a5_row5_col0" class="data row5 col0" >Bastion Username</td>
#       <td id="T_bc4a5_row5_col1" class="data row5 col1" >bschlue_0000009427</td>
#     </tr>
#     <tr>
#       <td id="T_bc4a5_row6_col0" class="data row6 col0" >Bastion Private Key File</td>
#       <td id="T_bc4a5_row6_col1" class="data row6 col1" >/home/fabric/work/fabric_config/bastion-key</td>
#     </tr>
#     <tr>
#       <td id="T_bc4a5_row7_col0" class="data row7 col0" >Slice Private Key File</td>
#       <td id="T_bc4a5_row7_col1" class="data row7 col1" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_bc4a5_row8_col0" class="data row8 col0" >Slice Public Key File</td>
#       <td id="T_bc4a5_row8_col1" class="data row8 col1" >/home/fabric/work/fabric_config/slice_key.pub</td>
#     </tr>
#     <tr>
#       <td id="T_bc4a5_row9_col0" class="data row9 col0" >Log File</td>
#       <td id="T_bc4a5_row9_col1" class="data row9 col1" >/tmp/fablib/fablib.log</td>
#     </tr>
#     <tr>
#       <td id="T_bc4a5_row10_col0" class="data row10 col0" >Log Level</td>
#       <td id="T_bc4a5_row10_col1" class="data row10 col1" >INFO</td>
#     </tr>
#     <tr>
#       <td id="T_bc4a5_row11_col0" class="data row11 col0" >Sites to avoid</td>
#       <td id="T_bc4a5_row11_col1" class="data row11 col1" ></td>
#     </tr>
#     <tr>
#       <td id="T_bc4a5_row12_col0" class="data row12 col0" >SSH Command Line</td>
#       <td id="T_bc4a5_row12_col1" class="data row12 col1" >ssh -i {{ _self_.private_ssh_key_file }} -F /home/fabric/work/fabric_config/ssh_config {{ _self_.username }}@{{ _self_.management_ip }}</td>
#     </tr>
#     <tr>
#       <td id="T_bc4a5_row13_col0" class="data row13 col0" >Version</td>
#       <td id="T_bc4a5_row13_col1" class="data row13 col1" >1.8.0</td>
#     </tr>
#     <tr>
#       <td id="T_bc4a5_row14_col0" class="data row14 col0" >Data directory</td>
#       <td id="T_bc4a5_row14_col1" class="data row14 col1" >/tmp/fablib</td>
#     </tr>
#     <tr>
#       <td id="T_bc4a5_row15_col0" class="data row15 col0" >Core API</td>
#       <td id="T_bc4a5_row15_col1" class="data row15 col1" >uis.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_bc4a5_row16_col0" class="data row16 col0" >Artifact Manager</td>
#       <td id="T_bc4a5_row16_col1" class="data row16 col1" >artifacts.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_bc4a5_row17_col0" class="data row17 col0" >Bastion SSH Config File</td>
#       <td id="T_bc4a5_row17_col1" class="data row17 col1" >/home/fabric/work/fabric_config/ssh_config</td>
#     </tr>
#     <tr>
#       <td id="T_bc4a5_row18_col0" class="data row18 col0" >Project Name</td>
#       <td id="T_bc4a5_row18_col1" class="data row18 col1" >FABRIC Clemson EDU</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_bc4a5 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_bc4a5 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_bc4a5 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_bc4a5_row0_col0, #T_bc4a5_row0_col1, #T_bc4a5_row1_col0, #T_bc4a5_row1_col1, #T_bc4a5_row2_col0, #T_bc4a5_row2_col1, #T_bc4a5_row3_col0, #T_bc4a5_row3_col1, #T_bc4a5_row4_col0, #T_bc4a5_row4_col1, #T_bc4a5_row5_col0, #T_bc4a5_row5_col1, #T_bc4a5_row6_col0, #T_bc4a5_row6_col1, #T_bc4a5_row7_col0, #T_bc4a5_row7_col1, #T_bc4a5_row8_col0, #T_bc4a5_row8_col1, #T_bc4a5_row9_col0, #T_bc4a5_row9_col1, #T_bc4a5_row10_col0, #T_bc4a5_row10_col1, #T_bc4a5_row11_col0, #T_bc4a5_row11_col1, #T_bc4a5_row12_col0, #T_bc4a5_row12_col1, #T_bc4a5_row13_col0, #T_bc4a5_row13_col1, #T_bc4a5_row14_col0, #T_bc4a5_row14_col1, #T_bc4a5_row15_col0, #T_bc4a5_row15_col1, #T_bc4a5_row16_col0, #T_bc4a5_row16_col1, #T_bc4a5_row17_col0, #T_bc4a5_row17_col1, #T_bc4a5_row18_col0, #T_bc4a5_row18_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_bc4a5">
#   <caption>FABlib Config</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_bc4a5_row0_col0" class="data row0 col0" >Credential Manager</td>
#       <td id="T_bc4a5_row0_col1" class="data row0 col1" >cm.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_bc4a5_row1_col0" class="data row1 col0" >Orchestrator</td>
#       <td id="T_bc4a5_row1_col1" class="data row1 col1" >orchestrator.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_bc4a5_row2_col0" class="data row2 col0" >Project ID</td>
#       <td id="T_bc4a5_row2_col1" class="data row2 col1" >0508639f-d515-44c8-b922-cf4cf000b6d9</td>
#     </tr>
#     <tr>
#       <td id="T_bc4a5_row3_col0" class="data row3 col0" >Token File</td>
#       <td id="T_bc4a5_row3_col1" class="data row3 col1" >/home/fabric/.tokens.json</td>
#     </tr>
#     <tr>
#       <td id="T_bc4a5_row4_col0" class="data row4 col0" >Bastion Host</td>
#       <td id="T_bc4a5_row4_col1" class="data row4 col1" >bastion.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_bc4a5_row5_col0" class="data row5 col0" >Bastion Username</td>
#       <td id="T_bc4a5_row5_col1" class="data row5 col1" >bschlue_0000009427</td>
#     </tr>
#     <tr>
#       <td id="T_bc4a5_row6_col0" class="data row6 col0" >Bastion Private Key File</td>
#       <td id="T_bc4a5_row6_col1" class="data row6 col1" >/home/fabric/work/fabric_config/bastion-key</td>
#     </tr>
#     <tr>
#       <td id="T_bc4a5_row7_col0" class="data row7 col0" >Slice Private Key File</td>
#       <td id="T_bc4a5_row7_col1" class="data row7 col1" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_bc4a5_row8_col0" class="data row8 col0" >Slice Public Key File</td>
#       <td id="T_bc4a5_row8_col1" class="data row8 col1" >/home/fabric/work/fabric_config/slice_key.pub</td>
#     </tr>
#     <tr>
#       <td id="T_bc4a5_row9_col0" class="data row9 col0" >Log File</td>
#       <td id="T_bc4a5_row9_col1" class="data row9 col1" >/tmp/fablib/fablib.log</td>
#     </tr>
#     <tr>
#       <td id="T_bc4a5_row10_col0" class="data row10 col0" >Log Level</td>
#       <td id="T_bc4a5_row10_col1" class="data row10 col1" >INFO</td>
#     </tr>
#     <tr>
#       <td id="T_bc4a5_row11_col0" class="data row11 col0" >Sites to avoid</td>
#       <td id="T_bc4a5_row11_col1" class="data row11 col1" ></td>
#     </tr>
#     <tr>
#       <td id="T_bc4a5_row12_col0" class="data row12 col0" >SSH Command Line</td>
#       <td id="T_bc4a5_row12_col1" class="data row12 col1" >ssh -i {{ _self_.private_ssh_key_file }} -F /home/fabric/work/fabric_config/ssh_config {{ _self_.username }}@{{ _self_.management_ip }}</td>
#     </tr>
#     <tr>
#       <td id="T_bc4a5_row13_col0" class="data row13 col0" >Version</td>
#       <td id="T_bc4a5_row13_col1" class="data row13 col1" >1.8.0</td>
#     </tr>
#     <tr>
#       <td id="T_bc4a5_row14_col0" class="data row14 col0" >Data directory</td>
#       <td id="T_bc4a5_row14_col1" class="data row14 col1" >/tmp/fablib</td>
#     </tr>
#     <tr>
#       <td id="T_bc4a5_row15_col0" class="data row15 col0" >Core API</td>
#       <td id="T_bc4a5_row15_col1" class="data row15 col1" >uis.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_bc4a5_row16_col0" class="data row16 col0" >Artifact Manager</td>
#       <td id="T_bc4a5_row16_col1" class="data row16 col1" >artifacts.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_bc4a5_row17_col0" class="data row17 col0" >Bastion SSH Config File</td>
#       <td id="T_bc4a5_row17_col1" class="data row17 col1" >/home/fabric/work/fabric_config/ssh_config</td>
#     </tr>
#     <tr>
#       <td id="T_bc4a5_row18_col0" class="data row18 col0" >Project Name</td>
#       <td id="T_bc4a5_row18_col1" class="data row18 col1" >FABRIC Clemson EDU</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Setup constants
cores = 1
ram = 2
disk = 10
nBots = 4
nNodes = 3 + nBots

# %%
# Define and Submit Slice
slice_name = "ECE6400-Final-DDoS-Sim"
site = "EDUKY"
print(site)

nicmodel = "NIC_Basic"
image = "default_ubuntu_20"

botNodes = [None] * nBots
network_interfaces = [None] * nNodes

slice = fablib.new_slice(name=slice_name)

# Create all of the nodes for the network
userNode = slice.add_node(name="User", site=site)
userNode.set_capacities(cores=cores, ram=ram, disk=disk)
userNode.set_image(image)    
user_ap = userNode.add_component(model=nicmodel, name="user-nic").get_interfaces()[0]
network_interfaces[nNodes - 3] = user_ap

targetNode = slice.add_node(name="Target", site=site)
targetNode.set_capacities(cores=cores, ram=ram, disk=disk)
targetNode.set_image(image)    
target_ap = targetNode.add_component(model=nicmodel, name="target-nic").get_interfaces()[0] 
network_interfaces[nNodes - 2] = target_ap

for i in range(0, nBots):
    botNodes[i] = slice.add_node(name="Bot_" + str(i), site=site)
    botNodes[i].set_capacities(cores=cores, ram=ram, disk=disk)
    botNodes[i].set_image(image)    
    network_interfaces[i] = botNodes[i].add_component(model=nicmodel, name="bot-nic-" + str(i)).get_interfaces()[0] 

controllerNode = slice.add_node(name="Controller", site=site)
controllerNode.set_capacities(cores=cores, ram=ram, disk=disk)
controllerNode.set_image(image)    
controller_ap = controllerNode.add_component(model=nicmodel, name="controller-nic").get_interfaces()[0]
network_interfaces[nNodes - 1] = controller_ap

# Network
l2_network = slice.add_l2network(name="network", interfaces=network_interfaces)


#Submit Slice Request
slice.submit()
# Out:
# Retry: 10, Time: 279 sec
# <style type="text/css">
# #T_d2ebd tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_d2ebd tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_d2ebd caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_d2ebd_row0_col0, #T_d2ebd_row0_col1, #T_d2ebd_row1_col0, #T_d2ebd_row1_col1, #T_d2ebd_row2_col0, #T_d2ebd_row2_col1, #T_d2ebd_row3_col0, #T_d2ebd_row3_col1, #T_d2ebd_row4_col0, #T_d2ebd_row4_col1, #T_d2ebd_row5_col0 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# #T_d2ebd_row5_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# </style>
# <table id="T_d2ebd">
#   <caption>Slice</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d2ebd_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_d2ebd_row0_col1" class="data row0 col1" >3a20d9cb-9467-40f8-9fff-60b30f741e46</td>
#     </tr>
#     <tr>
#       <td id="T_d2ebd_row1_col0" class="data row1 col0" >Name</td>
#       <td id="T_d2ebd_row1_col1" class="data row1 col1" >ECE6400-Final-DDoS-Sim</td>
#     </tr>
#     <tr>
#       <td id="T_d2ebd_row2_col0" class="data row2 col0" >Lease Expiration (UTC)</td>
#       <td id="T_d2ebd_row2_col1" class="data row2 col1" >2025-04-01 18:33:28 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_d2ebd_row3_col0" class="data row3 col0" >Lease Start (UTC)</td>
#       <td id="T_d2ebd_row3_col1" class="data row3 col1" >2025-03-31 18:33:28 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_d2ebd_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_d2ebd_row4_col1" class="data row4 col1" >0508639f-d515-44c8-b922-cf4cf000b6d9</td>
#     </tr>
#     <tr>
#       <td id="T_d2ebd_row5_col0" class="data row5 col0" >State</td>
#       <td id="T_d2ebd_row5_col1" class="data row5 col1" >StableOK</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_41452 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_41452 th {
#   text-align: left;
# }
# #T_41452 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_41452 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_41452 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_41452_row0_col0, #T_41452_row0_col1, #T_41452_row0_col2, #T_41452_row0_col3, #T_41452_row0_col4, #T_41452_row0_col5, #T_41452_row0_col6, #T_41452_row0_col7, #T_41452_row0_col8, #T_41452_row0_col9, #T_41452_row0_col10, #T_41452_row0_col13, #T_41452_row0_col14, #T_41452_row0_col15, #T_41452_row1_col0, #T_41452_row1_col1, #T_41452_row1_col2, #T_41452_row1_col3, #T_41452_row1_col4, #T_41452_row1_col5, #T_41452_row1_col6, #T_41452_row1_col7, #T_41452_row1_col8, #T_41452_row1_col9, #T_41452_row1_col10, #T_41452_row1_col13, #T_41452_row1_col14, #T_41452_row1_col15, #T_41452_row2_col0, #T_41452_row2_col1, #T_41452_row2_col2, #T_41452_row2_col3, #T_41452_row2_col4, #T_41452_row2_col5, #T_41452_row2_col6, #T_41452_row2_col7, #T_41452_row2_col8, #T_41452_row2_col9, #T_41452_row2_col10, #T_41452_row2_col13, #T_41452_row2_col14, #T_
row1_col13" class="data row1 col13" >ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config ubuntu@2610:1e0:1700:206:f816:3eff:fe44:8b8d</td>
#       <td id="T_41452_row1_col14" class="data row1 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_41452_row1_col15" class="data row1 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_41452_row2_col0" class="data row2 col0" >5f9a104d-9728-4bc7-9770-e7ec8e0df2bf</td>
#       <td id="T_41452_row2_col1" class="data row2 col1" >Bot_2</td>
#       <td id="T_41452_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_41452_row2_col3" class="data row2 col3" >2</td>
#       <td id="T_41452_row2_col4" class="data row2 col4" >10</td>
#       <td id="T_41452_row2_col5" class="data row2 col5" >default_ubuntu_20</td>
#       <td id="T_41452_row2_col6" class="data row2 col6" >qcow2</td>
#       <td id="T_41452_row2_col7" class="data row2 col7" >eduky-w14.fabric-testbed.net</td>
#       <td id="T_41452_row2_col8" class="data row2 col8" >EDUKY</td>
#       <td id="T_41452_row2_col9" class="data row2 col9" >ubuntu</td>
#       <td id="T_41452_row2_col10" c
# <style type="text/css">
# #T_ad711 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_ad711 th {
#   text-align: left;
# }
# #T_ad711 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_ad711 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_ad711 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_ad711_row0_col0, #T_ad711_row0_col1, #T_ad711_row0_col2, #T_ad711_row0_col3, #T_ad711_row0_col4, #T_ad711_row0_col5, #T_ad711_row0_col6 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T_ad711_row0_col7 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# #T_ad711_row0_col8 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# </style>
# <table id="T_ad711">
#   <caption>Networks</caption>
#   <thead>
#     <tr>
#       <th id="T_ad711_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_ad711_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_ad711_level0_col2" class="col_heading level0 col2" >Layer</th>
#       <th id="T_ad711_level0_col3" class="col_heading level0 col3" >Type</th>
#       <th id="T_ad711_level0_col4" class="col_heading level0 col4" >Site</th>
#       <th id="T_ad711_level0_col5" class="col_heading level0 col5" >Subnet</th>
#       <th id="T_ad711_level0_col6" class="col_heading level0 col6" >Gateway</th>
#       <th id="T_ad711_level0_col7" class="col_heading level0 col7" >State</th>
#       <th id="T_ad711_level0_col8" class="col_heading level0 col8" >Error</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ad711_row0_col0" class="data row0 col0" >6d3057c7-e2c9-4c2a-9f22-b05c2889d943</td>
#       <td id="T_ad711_row0_col1" class="data row0 col1" >tu_bridge</td>
#       <td id="T_ad711_row0_col2" class="data row0 col2" >L2</td>
#       <td id="T_ad711_row0_col3" class="data row0 col3" >L2Bridge</td>
#       <td id="T_ad711_row0_col4" class="data row0 col4" >EDUKY</td>
#       <td id="T_ad711_row0_col5" class="data row0 col5" >None</td>
#       <td id="T_ad711_row0_col6" class="data row0 col6" >None</td>
#       <td id="T_ad711_row0_col7" class="data row0 col7" >Active</td>
#       <td id="T_ad711_row0_col8" class="data row0 col8" ></td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_6cf1d caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_6cf1d th {
#   text-align: left;
# }
# #T_6cf1d tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_6cf1d tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_6cf1d .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_6cf1d_row0_col0, #T_6cf1d_row0_col1, #T_6cf1d_row0_col2, #T_6cf1d_row0_col3, #T_6cf1d_row0_col4, #T_6cf1d_row0_col5, #T_6cf1d_row0_col6, #T_6cf1d_row0_col7, #T_6cf1d_row0_col8, #T_6cf1d_row0_col9, #T_6cf1d_row0_col10, #T_6cf1d_row0_col11, #T_6cf1d_row0_col12, #T_6cf1d_row1_col0, #T_6cf1d_row1_col1, #T_6cf1d_row1_col2, #T_6cf1d_row1_col3, #T_6cf1d_row1_col4, #T_6cf1d_row1_col5, #T_6cf1d_row1_col6, #T_6cf1d_row1_col7, #T_6cf1d_row1_col8, #T_6cf1d_row1_col9, #T_6cf1d_row1_col10, #T_6cf1d_row1_col11, #T_6cf1d_row1_col12, #T_6cf1d_row2_col0, #T_6cf1d_row2_col1, #T_6cf1d_row2_col2, #T_6cf1d_row2_col3, #T_6cf1d_row2_col4, #T_6cf1d_row2_col5, #T_6cf1d_row2_col6, #T_6cf1d_row2_col7, #T_6cf1d_row2_col8, #T_6cf1d_row2_col9, #T_6cf1d_row2_col10, #T_6cf1d_row2_col11, #T_6cf1d_row2_col12, #T_6cf1d_row3_col0, #T_6cf1d_row3_col1, #T_6cf1d_row3_col2, #T_6cf1d_row3_col3, #T_6cf1d_row3_col4, #T_6cf1d_row3_col5, #T_6cf1d_row3_col6, #T_6cf1d_row3_col7, #T_6cf1d_row3_col8, #T_6cf1d_row3_col9, #T_6cf1d_row3_col10, #T_6cf1d_row3_col11, #T_6cf1d_row3_col12, #T_6cf1d_row4_col0, #T_6cf1d_row4_col1, #T_6cf1d_row4_col2, #T_6cf1d_row4_col3, #T_6cf1d_row4_col4, #T_6cf1d_row4
row2_col5" class="data row2 col5" >config</td>
#       <td id="T_6cf1d_row2_col6" class="data row2 col6" ></td>
#       <td id="T_6cf1d_row2_col7" class="data row2 col7" >02:05:D6:28:EE:72</td>
#       <td id="T_6cf1d_row2_col8" class="data row2 col8" >enp7s0</td>
#       <td id="T_6cf1d_row2_col9" class="data row2 col9" >enp7s0</td>
#       <td id="T_6cf1d_row2_col10" class="data row2 col10" >fe80::5:d6ff:fe28:ee72</td>
#       <td id="T_6cf1d_row2_col11" class="data row2 col11" >1</td>
#       <td id="T_6cf1d_row2_col12" class="data row2 col12" >HundredGigE0/0/0/15</td>
#     </tr>
#     <tr>
#       <td id="T_6cf1d_row3_col0" class="data row3 col0" >Bot_1-bot-nic-1-p1</td>
#       <td id="T_6cf1d_row3_col1" class="data row3 col1" >p1</td>
#       <td id="T_6cf1d_row3_col2" class="data row3 col2" >Bot_1</td>
#       <td id="T_6cf1d_row3_col3" class="data row3 col3" >tu_bridge</td>
#       <td id="T_6cf1d_row3_col4" class="data row3 col4" >100</td>
#       <td id="T_6cf1d_row3_col5" class="data row3 col5" >config</td>
#       <td id="T_6cf1d_row3_col6" class="data row3 col6" ></td>
#       <td id="T_6cf1d_row3_col7" class="data row3 col7" >02:CA:17:2B:B5:49</td>
#       <td id="T_6cf1d_row3_col8" class="data row3 col8" >enp7s0</td>
#       <td id="T_6cf1d_row3_col9" class="data row3 col9" >enp7s0</td>
#       <td id="T_6cf1d_row3_col10" class="data row3 col10" >fe80::ca:17ff:fe2b:b549</td>
#       <td id="T_6cf1d_row3_col11" class="data row3 col11" >1</td>
#       <td id="T_6cf1d_row3_col12" class="data row3 col12" >HundredGigE0/0/0/19</td>
#     </tr>
#     <tr>
#       <td id="T_6cf1d_row4_col0" class="data row4 col0" >Bot_2-bot-nic-2-p1</td>
#       <td id="T_6cf1d_row4_col1" class="data row4 col1" >p1</td>
#       <td id="T_6cf1d_row4_col2" class="data row4 col2" >Bot_2</td>
#       <td id="T_6cf1d_row4_col3" class="data row4 col3" >tu_bridge</td>
#       <td id="T_6cf1d_row4_col4" class="data row4 col4" >100</td>
#       <td id="T_6cf1d_row4_col5" class="data row4 col5" >config</td>
#       <td id="T_6cf1d_row4_col6" class="data row4 col6" ></td>
#       <td id="T_6cf1d_row4_col7" class="data row4 col7" >06:8B:71:02:D8:17</td>
#       <td id="T_6cf1d_row4_col8" class="data row4 col8" >enp7s0</td>
#       <td id="T_6cf1d_row4_col9" clas
# Time to print interfaces 296 seconds
# '3a20d9cb-9467-40f8-9fff-60b30f741e46'

# %%
ip_user = "10.0.0.1"
ip_target = "10.0.0.2"
ip_controller = "10.0.0.254"

iface_bots = [None] * nBots

# get slice info 

bots = [None] * nBots

user = slice.get_node(name="User")
target = slice.get_node(name="Target")

for i in range(0, nBots):
    bots[i] = slice.get_node(name=f"Bot_{str(i)}")

controller = slice.get_node(name="Controller")

# remove any existing IP's from the interface to prevent duplicates from being added

user.execute("sudo ip addr flush enp7s0")
target.execute("sudo ip addr flush enp7s0")
controller.execute("sudo ip addr flush enp7s0")

for i in range(0, nBots):
    bots[i].execute("sudo ip addr flush enp7s0")

# set interface IP's
iface_user = user.get_interface(network_name="network")
iface_user.set_ip(ip=ip_user, cidr="16")

iface_target = target.get_interface(network_name="network") #target to user
iface_target.set_ip(ip=ip_target, cidr="16")

iface_controller = controller.get_interface(network_name="network")
iface_controller.set_ip(ip=ip_controller, cidr="16")

for i in range(0, nBots): 
    iface_bots[i] = bots[i].get_interface(network_name="network")
    iface_bots[i].set_ip(ip=f"10.0.1.{str(i)}", cidr="16")

# %%
# IP space where bot cannot access user (realistic)

# 10.0.0.x represents the network the client and the target share
# 10.0.1.x represents the network the client and bot share
# 192.168.0.x is the network all the bots and the controller are on

ip_user = "10.0.0.1"
ip_target_u = "10.0.0.2"
ip_target_b = "10.0.1.1"
ip_bot_t = "10.0.1.2"
ip_bot_c = "192.168.0.1"
ip_controller = "192.168.0.254"

bots = [None] * nBots

user = slice.get_node(name="User")
target = slice.get_node(name="Target")

for i in range(0, nBots):
    bots[i] = slice.get_node(name=f"Bot_{str(i)}")

controller = slice.get_node(name="Controller")

# remove any existing IP's from the interface to prevent duplicates from being added
user.execute("sudo ip addr flush enp7s0")

for i in range(0, nBots):
    target.execute("sudo ip addr flush enp7s0")
    bot.execute("sudo ip addr flush enp7s0")
    target.execute("sudo ip addr flush enp8s0")
    bot.execute("sudo ip addr flush enp8s0")
    
controller.execute("sudo ip addr flush enp7s0")

# set interface IP's
iface_user = user.get_interface(network_name="tu_bridge")
iface_user.set_ip(ip=ip_user, cidr="24")

iface_target_u = target.get_interface(network_name="tu_bridge") #target to user
iface_target_u.set_ip(ip=ip_target_u, cidr="24")
iface_target_b = target.get_interface(network_name="bt_bridge") #target to bot
iface_target_b.set_ip(ip=ip_target_b, cidr="24")

iface_bot_t = bot.get_interface(network_name="bt_bridge") #bot to target
iface_bot_t.set_ip(ip=ip_bot_t, cidr="24")
iface_bot_c = bot.get_interface(network_name="cb_bridge") #bot to controller
iface_bot_c.set_ip(ip=ip_bot_c, cidr="24")

iface_controller = controller.get_interface(network_name="cb_bridge")
iface_controller.set_ip(ip=ip_controller, cidr="24")
# Out:
# '\nclient_name = "client"\nserver_name = "server"\nnetwork_service_name = "bridge1"\n\nclient_ip = \'10.20.30.40\'\nserver_ip = \'10.20.30.41\'\n\nclient = slice.get_node(name=client_name)        \niface1 = client.get_interface(network_name=network_service_name)  \niface1.set_ip(ip=client_ip, cidr="24")\n\niface1.get_device_name()\n\nclient.execute("echo 100.20.30.40 client | sudo tee -a /etc/hosts")\nclient.execute(f"sudo ip link set dev { iface1.get_device_name()} up")\n\nstdout, stderr = client.execute(f\'ip addr show {iface1.get_os_interface()}\')\nserver = slice.get_node(name=server_name)        \niface2 = server.get_interface(network_name=network_service_name)  \niface2.set_ip(ip=server_ip, cidr="24")\n\nstdout, stderr = server.execute(f\'ip addr show {iface2.get_os_interface()}\')\nserver.execute(f"sudo ip link set dev { iface2.get_device_name()} up")\n\nprint("Printing Server\'s Network")\nout, err = server.execute("ip a ")\n\nprint("Getting control interface ip")\nout, err = server.execute("ip a | grep inet | grep enp | awk \'{print $2}\'")\nip = ((out.split(\'\n\')[0]).split(\'/\'))[0]\nprint(f"Ip found: {ip}")\n\nprint("Getting Client\'s interface name")\nprint(f\'Device Found: {iface1.get_device_name()}\')\n\n# add route if needed\nclient.execute(f"sudo ip route add {ip} dev {iface1.get_device_name()}")\n'

# %%
# Delete Slice
try:
    #To delete the slice change "CHECK" to "True", this is to prevent accidental slice deletion
    CHECK = True
    if (CHECK):
        slice = fablib.get_slice(slice_name)
        slice.delete()
    else:
        print("Change the Boolean to delete slice")
except Exception as e:
    print(f"Fail: {e}")
