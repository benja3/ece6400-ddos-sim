# %% [markdown]
# ## 1. Retrieve Slice
# For initial stages, using CreateSlice.ipynb from `/teaching-materials/teaching-materials/assignments/Exploring Queues`

# %%
# Load Fablib and Node Information
from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager
fablib = fablib_manager() 
fablib.show_config()
import json
import traceback
import time

slice_name = "ECE6400-Final-DDoS-Sim"
slice = fablib.get_slice(slice_name)
slice.list_nodes()
# Out:
# <style type="text/css">
# #T_4d7fb tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_4d7fb tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_4d7fb caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_4d7fb_row0_col0, #T_4d7fb_row0_col1, #T_4d7fb_row1_col0, #T_4d7fb_row1_col1, #T_4d7fb_row2_col0, #T_4d7fb_row2_col1, #T_4d7fb_row3_col0, #T_4d7fb_row3_col1, #T_4d7fb_row4_col0, #T_4d7fb_row4_col1, #T_4d7fb_row5_col0, #T_4d7fb_row5_col1, #T_4d7fb_row6_col0, #T_4d7fb_row6_col1, #T_4d7fb_row7_col0, #T_4d7fb_row7_col1, #T_4d7fb_row8_col0, #T_4d7fb_row8_col1, #T_4d7fb_row9_col0, #T_4d7fb_row9_col1, #T_4d7fb_row10_col0, #T_4d7fb_row10_col1, #T_4d7fb_row11_col0, #T_4d7fb_row11_col1, #T_4d7fb_row12_col0, #T_4d7fb_row12_col1, #T_4d7fb_row13_col0, #T_4d7fb_row13_col1, #T_4d7fb_row14_col0, #T_4d7fb_row14_col1, #T_4d7fb_row15_col0, #T_4d7fb_row15_col1, #T_4d7fb_row16_col0, #T_4d7fb_row16_col1, #T_4d7fb_row17_col0, #T_4d7fb_row17_col1, #T_4d7fb_row18_col0, #T_4d7fb_row18_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_4d7fb">
#   <caption>FABlib Config</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_4d7fb_row0_col0" class="data row0 col0" >Orchestrator</td>
#       <td id="T_4d7fb_row0_col1" class="data row0 col1" >orchestrator.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_4d7fb_row1_col0" class="data row1 col0" >Credential Manager</td>
#       <td id="T_4d7fb_row1_col1" class="data row1 col1" >cm.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_4d7fb_row2_col0" class="data row2 col0" >Core API</td>
#       <td id="T_4d7fb_row2_col1" class="data row2 col1" >uis.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_4d7fb_row3_col0" class="data row3 col0" >Artifact Manager</td>
#       <td id="T_4d7fb_row3_col1" class="data row3 col1" >artifacts.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_4d7fb_row4_col0" class="data row4 col0" >Token File</td>
#       <td id="T_4d7fb_row4_col1" class="data row4 col1" >/home/fabric/.tokens.json</td>
#     </tr>
#     <tr>
#       <td id="T_4d7fb_row5_col0" class="data row5 col0" >Project ID</td>
#       <td id="T_4d7fb_row5_col1" class="data row5 col1" >5be8419d-0ad5-4c79-8396-258fc7e893f5</td>
#     </tr>
#     <tr>
#       <td id="T_4d7fb_row6_col0" class="data row6 col0" >Bastion Host</td>
#       <td id="T_4d7fb_row6_col1" class="data row6 col1" >bastion.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_4d7fb_row7_col0" class="data row7 col0" >Bastion Username</td>
#       <td id="T_4d7fb_row7_col1" class="data row7 col1" >kguerns_0000197554</td>
#     </tr>
#     <tr>
#       <td id="T_4d7fb_row8_col0" class="data row8 col0" >Bastion Private Key File</td>
#       <td id="T_4d7fb_row8_col1" class="data row8 col1" >/home/fabric/work/fabric_config/fabric_bastion_key</td>
#     </tr>
#     <tr>
#       <td id="T_4d7fb_row9_col0" class="data row9 col0" >Slice Public Key File</td>
#       <td id="T_4d7fb_row9_col1" class="data row9 col1" >/home/fabric/work/fabric_config/slice_key.pub</td>
#     </tr>
#     <tr>
#       <td id="T_4d7fb_row10_col0" class="data row10 col0" >Slice Private Key File</td>
#       <td id="T_4d7fb_row10_col1" class="data row10 col1" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_4d7fb_row11_col0" class="data row11 col0" >Sites to avoid</td>
#       <td id="T_4d7fb_row11_col1" class="data row11 col1" ></td>
#     </tr>
#     <tr>
#       <td id="T_4d7fb_row12_col0" class="data row12 col0" >SSH Command Line</td>
#       <td id="T_4d7fb_row12_col1" class="data row12 col1" >ssh -i {{ _self_.private_ssh_key_file }} -F /home/fabric/work/fabric_config/ssh_config {{ _self_.username }}@{{ _self_.management_ip }}</td>
#     </tr>
#     <tr>
#       <td id="T_4d7fb_row13_col0" class="data row13 col0" >Log Level</td>
#       <td id="T_4d7fb_row13_col1" class="data row13 col1" >INFO</td>
#     </tr>
#     <tr>
#       <td id="T_4d7fb_row14_col0" class="data row14 col0" >Log File</td>
#       <td id="T_4d7fb_row14_col1" class="data row14 col1" >/tmp/fablib/fablib.log</td>
#     </tr>
#     <tr>
#       <td id="T_4d7fb_row15_col0" class="data row15 col0" >Bastion SSH Config File</td>
#       <td id="T_4d7fb_row15_col1" class="data row15 col1" >/home/fabric/work/fabric_config/ssh_config</td>
#     </tr>
#     <tr>
#       <td id="T_4d7fb_row16_col0" class="data row16 col0" >Version</td>
#       <td id="T_4d7fb_row16_col1" class="data row16 col1" >1.8.1</td>
#     </tr>
#     <tr>
#       <td id="T_4d7fb_row17_col0" class="data row17 col0" >Data directory</td>
#       <td id="T_4d7fb_row17_col1" class="data row17 col1" >/tmp/fablib</td>
#     </tr>
#     <tr>
#       <td id="T_4d7fb_row18_col0" class="data row18 col0" >Project Name</td>
#       <td id="T_4d7fb_row18_col1" class="data row18 col1" >Clemson ECE 4380-6380</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_491e6 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_491e6 th {
#   text-align: left;
# }
# #T_491e6 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_491e6 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_491e6 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_491e6_row0_col0, #T_491e6_row0_col1, #T_491e6_row0_col2, #T_491e6_row0_col3, #T_491e6_row0_col4, #T_491e6_row0_col5, #T_491e6_row0_col6, #T_491e6_row0_col7, #T_491e6_row0_col8, #T_491e6_row0_col9, #T_491e6_row0_col10, #T_491e6_row0_col11, #T_491e6_row0_col12, #T_491e6_row0_col13, #T_491e6_row0_col14, #T_491e6_row0_col15, #T_491e6_row1_col0, #T_491e6_row1_col1, #T_491e6_row1_col2, #T_491e6_row1_col3, #T_491e6_row1_col4, #T_491e6_row1_col5, #T_491e6_row1_col6, #T_491e6_row1_col7, #T_491e6_row1_col8, #T_491e6_row1_col9, #T_491e6_row1_col10, #T_491e6_row1_col11, #T_491e6_row1_col12, #T_491e6_row1_col13, #T_491e6_row1_col14, #T_491e6_row1_col15, #T_491e6_row2_col0, #T_491e6_row2_col1, #T_491e6_row2_col2, #T_491e6_row
row2_col11" class="data row2 col11" >Active</td>
#       <td id="T_491e6_row2_col12" class="data row2 col12" ></td>
#       <td id="T

# %% [markdown]
# ### 2. Load Nodes

# %%
# Setup constants
nBots = 4

# Load nodes
bots = [slice.get_node(name=f"Bot_{i}") for i in range(nBots)]
target = slice.get_node(name="Target")
controller = slice.get_node(name="Controller")
user = slice.get_node(name="User")

ip_target = "10.0.0.2"

# %% [markdown]
# ### 3. Baseline Metric Collection

# %%
#print("\n===== Collect Baseline Metrics =====")
#print("\n--- Baseline Latency & Packet Loss (Target -> Controller) ---")
#print(target.execute(f"ping -i 0.5 -c 20 {controller.get_management_ip()}"))

#print("\n--- Baseline Latency & Packet Loss (User -> Target) ---")
#print(user.execute(f"ping -i 0.5 -c 20 {ip_target}"))

#print("\n--- Baseline Queue Status on Target ---")
#print(target.execute("sudo tc -s qdisc show dev enp7s0"))

#print("\n--- Baseline CPU Usage on Target ---")
#print(target.execute("top -bn1 | head -n 10"))

#print("\n--- Baseline Network Traffic Stats on Target ---")
#print(target.execute("ifconfig enp7s0"))

#time.sleep(2)
# Out:
# ===== Collect Baseline Metrics =====
#
# --- Baseline Latency & Packet Loss (Target -> Controller) ---
# PING 2610:1e0:1700:206:f816:3eff:fed9:c7e7(2610:1e0:1700:206:f816:3eff:fed9:c7e7) 56 data bytes
# 64 bytes from 2610:1e0:1700:206:f816:3eff:fed9:c7e7: icmp_seq=1 ttl=64 time=2.37 ms
# 64 bytes from 2610:1e0:1700:206:f816:3eff:fed9:c7e7: icmp_seq=2 ttl=64 time=0.331 ms
# 64 bytes from 2610:1e0:1700:206:f816:3eff:fed9:c7e7: icmp_seq=3 ttl=64 time=0.370 ms
# 64 bytes from 2610:1e0:1700:206:f816:3eff:fed9:c7e7: icmp_seq=4 ttl=64 time=0.279 ms
# 64 bytes from 2610:1e0:1700:206:f816:3eff:fed9:c7e7: icmp_seq=5 ttl=64 time=0.311 ms
# 64 bytes from 2610:1e0:1700:206:f816:3eff:fed9:c7e7: icmp_seq=6 ttl=64 time=0.318 ms
# 64 bytes from 2610:1e0:1700:206:f816:3eff:fed9:c7e7: icmp_seq=7 ttl=64 time=0.292 ms
# 64 bytes from 2610:1e0:1700:206:f816:3eff:fed9:c7e7: icmp_seq=8 ttl=64 time=0.320 ms
# 64 bytes from 2610:1e0:1700:206:f816:3eff:fed9:c7e7: icmp_seq=9 ttl=64 time=0.380 ms
# 64 bytes from 2610:1e0:1700:206:f816:3eff:fed9:c7e7: icmp_seq=10 ttl=64 time=0.312 ms
# 64 bytes from 2610:1e0:1700:206:f816:3eff:fed9:c7e7: icmp_seq=11 ttl=64 time=0.290 ms
# 64 bytes from 2610:1e0:1700:206:f816:3eff:fed9:c7e7: icmp_seq=12 ttl=64 time=0.306 ms
# 64 bytes from 2610:1e0:1700:206:f816:3eff:fed9:c7e7: icmp_seq=13 ttl=64 time=0.291 ms
# 64 bytes from 2610:1e0:1700:206:f816:3eff:fed9:c7e7: icmp_seq=14 ttl=64 time=0.266 ms
# 64 bytes from 2610:1e0:1700:206:f816:3eff:fed9:c7e7: icmp_seq=15 ttl=64 time=0.325 ms
# 64 bytes from 2610:1e0:1700:206:f816:3eff:fed9:c7e7: icmp_seq=16 ttl=64 time=0.308 ms
# 64 bytes from 2610:1e0:1700:206:f816:3eff:fed9:c7e7: icmp_seq=17 ttl=64 time=0.292 ms
# 64 bytes from 2610:1e0:1700:206:f816:3eff:fed9:c7e7: icmp_seq=18 ttl=64 time=0.286 ms
# 64 bytes from 2610:1e0:1700:206:f816:3eff:fed9:c7e7: icmp_seq=19 ttl=64 time=0.330 ms
# 64 bytes from 2610:1e0:1700:206:f816:3eff:fed9:c7e7: icmp_seq=20 ttl=64 time=0.258 ms
#
# --- 2610:1e0:1700:206:f816:3eff:fed9:c7e7 ping statistics ---
# 20 packets transmitted, 20 received, 0% packet loss, time 9718ms
# rtt min/avg/max/mdev = 0.258/0.411/2.369/0.449 ms
# ('PING 2610:1e0:1700:206:f816:3eff:fed9:c7e7(2610:1e0:1700:206:f816:3eff:fed9:c7e7) 56 data bytes\n64 bytes from 2610:1e0:1700:206:f816:3eff:fed9:c7e7: icmp_seq=1 ttl=64 time=2.37 ms\n64 bytes from 2610:1e0:1700:206:f816:3eff:fed9:c7e7: icmp_seq=2 ttl=64 time=0.331 ms\n64 bytes from 2610:1e0:1700:206:f816:3eff:fed9:c7e7: icmp_seq=3 ttl=64 time=0.370 ms\n64 bytes from 2610:1e0:1700:206:f816:3eff:fed9:c7e7: icmp_seq=4 ttl=64 time=0.279 ms\n64 bytes from 2610:1e0:1700:206:f816:3eff:fed9:c7e7: icmp_seq=5 ttl=64 time=0.311 ms\n64 bytes from 2610:1e0:1700:206:f816:3eff:fed9:c7e7: icmp_seq=6 ttl=64 time=0.318 ms\n64 bytes from 2610:1e0:1700:206:f816:3eff:fed9:c7e7: icmp_seq=7 ttl=64 time=0.292 ms\n64 bytes from 2610:1e0:1700:206:f816:3eff:fed9:c7e7: icmp_seq=8 ttl=64 time=0.320 ms\n64 bytes from 2610:1e0:1700:206:f816:3eff:fed9:c7e7: icmp_seq=9 ttl=64 time=0.380 ms\n64 bytes from 2610:1e0:1700:206:f816:3eff:fed9:c7e7: icmp_seq=10 ttl=64 time=0.312 ms\n64 bytes from 2610:1e0:1700:206:f816:3eff:fed9:c7e7: icmp_seq=11 ttl=64 time=0.290 ms\n64 bytes from 2610:1e0:1700:206:f816:3eff:fed9:c7e7: icmp_seq=12 ttl=64 time=0.306 ms\n64 bytes from 2610:1e0:1700:206:f816:3eff:fed9:c7e7: icmp_seq=13 ttl=64 time=0.291 ms\n64 bytes from 2610:1e0:1700:206:f816:3eff:fed9:c7e7: icmp_seq=14 ttl=64 time=0.266 ms\n64 bytes from 2610:1e0:1700:206:f816:3eff:fed9:c7e7: icmp_seq=15 ttl=64 time=0.325 ms\n64 bytes from 2610:1e0:1700:206:f816:3eff:fed9:c7e7: icmp_seq=16 ttl=64 time=0.308 ms\n64 bytes from 2610:1e0:1700:206:f816:3eff:fed9:c7e7: icmp_seq=17 ttl=64 time=0.292 ms\n64 bytes from 2610:1e0:1700:206:f816:3eff:fed9:c7e7: icmp_seq=18 ttl=64 time=0.286 ms\n64 bytes from 2610:1e0:1700:206:f816:3eff:fed9:c7e7: icmp_seq=19 ttl=64 time=0.330 ms\n64 bytes from 2610:1e0:1700:206:f816:3eff:fed9:c7e7: icmp_seq=20 ttl=64 time=0.258 ms\n\n--- 2610:1e0:1700:206:f816:3eff:fed9:c7e7 ping statistics ---\n20 packets transmitted, 20 received, 0% packet loss, time 9718ms\nrtt min/avg/max/mdev = 0.258/0.411/2.369/0.449 ms\n', '')
#
# --- Baseline Latency & Packet Loss (User -> Target) ---
# PING 10.0.0.2 (10.0.0.2) 56(84) bytes of data.
# 64 bytes from 10.0.0.2: icmp_seq=1 ttl=64 time=0.199 ms
# 64 bytes from 10.0.0.2: icmp_seq=2 ttl=64 time=0.073 ms
# 64 bytes from 10.0.0.2: icmp_seq=3 ttl=64 time=0.073 ms
# 64 bytes from 10.0.0.2: icmp_seq=4 ttl=64 time=0.072 ms
# 64 bytes from 10.0.0.2: icmp_seq=5 ttl=64 time=0.073 ms
# 64 bytes from 10.0.0.2: icmp_seq=6 ttl=64 time=0.077 ms
# 64 bytes from 10.0.0.2: icmp_seq=7 ttl=64 time=0.075 ms
# 64 bytes from 10.0.0.2: icmp_seq=8 ttl=64 time=0.077 ms
# 64 bytes from 10.0.0.2: icmp_seq=9 ttl=64 time=0.076 ms
# 64 bytes from 10.0.0.2: icmp_seq=10 ttl=64 time=0.071 ms
# 64 bytes from 10.0.0.2: icmp_seq=11 ttl=64 time=0.064 ms
# 64 bytes from 10.0.0.2: icmp_seq=12 ttl=64 time=0.070 ms
# 64 bytes from 10.0.0.2: icmp_seq=13 ttl=64 time=0.063 ms
# 64 bytes from 10.0.0.2: icmp_seq=14 ttl=64 time=0.078 ms
# 64 bytes from 10.0.0.2: icmp_seq=15 ttl=64 time=0.064 ms
# 64 bytes from 10.0.0.2: icmp_seq=16 ttl=64 time=0.069 ms
# 64 bytes from 10.0.0.2: icmp_seq=17 ttl=64 time=0.071 ms
# 64 bytes from 10.0.0.2: icmp_seq=18 ttl=64 time=0.065 ms
# 64 bytes from 10.0.0.2: icmp_seq=19 ttl=64 time=0.078 ms
# 64 bytes from 10.0.0.2: icmp_seq=20 ttl=64 time=0.069 ms
#
# --- 10.0.0.2 ping statistics ---
# 20 packets transmitted, 20 received, 0% packet loss, time 9735ms
# rtt min/avg/max/mdev = 0.063/0.077/0.199/0.028 ms
# ('PING 10.0.0.2 (10.0.0.2) 56(84) bytes of data.\n64 bytes from 10.0.0.2: icmp_seq=1 ttl=64 time=0.199 ms\n64 bytes from 10.0.0.2: icmp_seq=2 ttl=64 time=0.073 ms\n64 bytes from 10.0.0.2: icmp_seq=3 ttl=64 time=0.073 ms\n64 bytes from 10.0.0.2: icmp_seq=4 ttl=64 time=0.072 ms\n64 bytes from 10.0.0.2: icmp_seq=5 ttl=64 time=0.073 ms\n64 bytes from 10.0.0.2: icmp_seq=6 ttl=64 time=0.077 ms\n64 bytes from 10.0.0.2: icmp_seq=7 ttl=64 time=0.075 ms\n64 bytes from 10.0.0.2: icmp_seq=8 ttl=64 time=0.077 ms\n64 bytes from 10.0.0.2: icmp_seq=9 ttl=64 time=0.076 ms\n64 bytes from 10.0.0.2: icmp_seq=10 ttl=64 time=0.071 ms\n64 bytes from 10.0.0.2: icmp_seq=11 ttl=64 time=0.064 ms\n64 bytes from 10.0.0.2: icmp_seq=12 ttl=64 time=0.070 ms\n64 bytes from 10.0.0.2: icmp_seq=13 ttl=64 time=0.063 ms\n64 bytes from 10.0.0.2: icmp_seq=14 ttl=64 time=0.078 ms\n64 bytes from 10.0.0.2: icmp_seq=15 ttl=64 time=0.064 ms\n64 bytes from 10.0.0.2: icmp_seq=16 ttl=64 time=0.069 ms\n64 bytes from 10.0.0.2: icmp_seq=17 ttl=64 time=0.071 ms\n64 bytes from 10.0.0.2: icmp_seq=18 ttl=64 time=0.065 ms\n64 bytes from 10.0.0.2: icmp_seq=19 ttl=64 time=0.078 ms\n64 bytes from 10.0.0.2: icmp_seq=20 ttl=64 time=0.069 ms\n\n--- 10.0.0.2 ping statistics ---\n20 packets transmitted, 20 received, 0% packet loss, time 9735ms\nrtt min/avg/max/mdev = 0.063/0.077/0.199/0.028 ms\n', '')
#
# --- Baseline Queue Status on Target ---
# qdisc mq 0: root
#  Sent 3090 bytes 35 pkt (dropped 0, overlimits 0 requeues 0)
#  backlog 0b 0p requeues 0
# qdisc fq_codel 0: parent :1 limit 10240p flows 1024 quantum 1514 target 5.0ms interval 100.0ms memory_limit 32Mb ecn
#  Sent 3090 bytes 35 pkt (dropped 0, overlimits 0 requeues 0)
#  backlog 0b 0p requeues 0
#   maxpacket 0 drop_overlimit 0 new_flow_count 0 ecn_mark 0
#   new_flows_len 0 old_flows_len 0
# ('qdisc mq 0: root \n Sent 3090 bytes 35 pkt (dropped 0, overlimits 0 requeues 0) \n backlog 0b 0p requeues 0\nqdisc fq_codel 0: parent :1 limit 10240p flows 1024 quantum 1514 target 5.0ms interval 100.0ms memory_limit 32Mb ecn \n Sent 3090 bytes 35 pkt (dropped 0, overlimits 0 requeues 0) \n backlog 0b 0p requeues 0\n  maxpacket 0 drop_overlimit 0 new_flow_count 0 ecn_mark 0\n  new_flows_len 0 old_flows_len 0\n', '')

# %% [markdown]
# ### 2. Sending instructions to the bots from the controller

# %%
import threading

# Reduce target's input rate to 1kb/s and set its queue size to 1kb
target.execute("sudo tc qdisc add dev enp7s0 root tbf rate 1kbit limit 1kb burst 10kb")

# Threading Functions
def start_ping_flood(bot, ip_target):
    try:
        bot.execute("sudo rm ping_output.txt")
        print(f"Starting ping flood attack from {bot.get_name()}...")
        bot.execute(f"nohup sudo ping -f -c 1000 {ip_target} > ping_output.txt 2>&1 &")
    except Exception as e:
        print(f"Error starting ping flood on {bot.get_name()}: {e}\n")

def start_user_ping(user, ip_target):
    try:
        user.execute("sudo rm ping_output.txt ping_pid.txt")
        print(f"Starting ping from {user.get_name()}...")
        user.execute(f"nohup sudo ping -i 0.2 -c 300 {ip_target} > ping_output.txt 2>&1 & echo $! > ping_pid.txt")
    except Exception as e:
        print(f"Error starting ping on {user.get_name()}: {e}\n")

def wait_for_ping_to_finish(bot):
    print(f"Waiting for {bot.get_name()} to finish ping flood...")
    while True:
        stdout, sterr = bot.execute("pgrep ping", quiet=True)
        if stdout.strip() == "":
            print(f"{bot.get_name()} finished.")
            break
        time.sleep(2)

def wait_for_ping_to_finish_user(bot):
    print(f"Waiting for {bot.get_name()} to finish ping flood...")
    stdout, stderr = bot.execute("cat ping_pid.txt", quiet=True)
    pid = stdout.strip()
    if pid == "":
        print(f"No PID file found on {bot.get_name()}.")
        return
    while True:
        stdout, stderr = bot.execute(f"ps -p {pid}", quiet=True)
        if "ping" not in stdout:
            print(f"{bot.get_name()} finished ping.")
            time.sleep(1)
            break
        time.sleep(2)

def collect_ping_results(bot):
    try:
        bot.download_file(f"{bot.get_name()}_ping_result.txt", "ping_output.txt")
        print(f"Svaed ping result for {bot.get_name()}")
    except Exception as e:
        print(f"Error saving ping result from {bot.get_name()}: {e}")

#download_file command to get output files from bot nodes to local machine

# Run User pings for duration of whole experiment
print("\n===== Starting Baseline Testing =====")
user_thread = threading.Thread(target=start_user_ping, args=(user, ip_target))
user_thread.start()

time.sleep(3)

# Start DDoS Attack Simulation
print("\n===== Starting DDoS Simulation =====")

# Launch threads
threads = []
for bot in bots:
    thread = threading.Thread(target=start_ping_flood, args=(bot, ip_target))
    thread.start()
    threads.append(thread)

# Wait for all threads to start (not needed to wait for them to finish)
for thread in threads:
    thread.join()
    
# Collect statistics

#print("\n===== Monitoring Effects During Attack =====")
#print("\n--- Latency & Packet Loss (Target -> Controller) ---")
#print(target.execute(f"ping -i 0.5 -c 20 {controller.get_management_ip()}"))

#print("\n--- Latency & Packet Loss (User -> Target) ---")


#print("\n--- CPU Usage on Target ---")
#print(target.execute("top -bn1 | head -n 10"))

#print("\n--- Network Traffic Stats on Target ---")
#print(target.execute("ifconfig enp7s0"))

# Wait for attack and user to end
print("\n===== Wait for DDoS Attack and User Pings to End =====")

for bot in bots:
    wait_for_ping_to_finish(bot)

wait_for_ping_to_finish_user(user)

# Collect Results
print("\n===== Collecting Results =====")

print("\n--- Queue Status on Target ---")
print(target.execute("sudo tc -s qdisc show dev enp7s0"))

for bot in bots:
    collect_ping_results(bot)

collect_ping_results(user)

print("\nRestoring normal network conditions.")
target.execute("sudo tc qdisc del dev enp7s0 root") # Remove queue limit
print("\nDDoS simulation complete. Network restored.")
# Out:
# ===== Starting Baseline Testing =====
# Starting ping from User...
#
# ===== Starting DDoS Simulation =====
# Starting ping flood attack from Bot_0...
# Starting ping flood attack from Bot_2...
# Starting ping flood attack from Bot_1...
# Starting ping flood attack from Bot_3...
#
# ===== Wait for DDoS Attack and User Pings to End =====
# Waiting for Bot_0 to finish ping flood...
# Bot_0 finished.
# Waiting for Bot_1 to finish ping flood...
# Bot_1 finished.
# Waiting for Bot_2 to finish ping flood...
# Bot_2 finished.
# Waiting for Bot_3 to finish ping flood...
# Bot_3 finished.
# Waiting for User to finish ping flood...
# User finished ping.
#
# ===== Collecting Results =====
#
# --- Queue Status on Target ---
# qdisc tbf 8016: root refcnt 9 rate 1Kbit burst 10Kb limit 1Kb
#  Sent 16884 bytes 186 pkt (dropped 3994, overlimits 4241 requeues 0)
#  backlog 812b 10p requeues 0
# ('qdisc tbf 8016: root refcnt 9 rate 1Kbit burst 10Kb limit 1Kb \n Sent 16884 bytes 186 pkt (dropped 3994, overlimits 4241 requeues 0) \n backlog 812b 10p requeues 0\n', '')
# Svaed ping result for Bot_0
# Svaed ping result for Bot_1
# Svaed ping result for Bot_2
# Svaed ping result for Bot_3
# Svaed ping result for User
#
# Restoring normal network conditions.
#
# DDoS simulation complete. Network restored.

# %% [markdown]
# ### 3. Cleanup Resources

# %%
# Delete Slice
try:
    #To delete the slice change "CHECK" to "True", this is to prevent accidental slice deletion
    CHECK = False
    if (CHECK):
        slice = fablib.get_slice(slice_name)
        slice.delete()
    else:
        print("Change the Boolean to delete slice")
except Exception as e:
    print(f"Fail: {e}")
